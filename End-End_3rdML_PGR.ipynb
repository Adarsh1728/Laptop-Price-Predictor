# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(29)

# %%
df.isna().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True,errors='ignore')

# %%
df['Ram']=df['Ram'].str.replace('GB',' ')
df['Weight']=df['Weight'].str.replace('kg',' ')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# ## 1.EDA

# %%
plt.Figure(figsize=(15,10))
sns.distplot(df['Price'],color='Green')
# Out:
# C:\Users\Adarsh1728\AppData\Local\Temp\ipykernel_16284\2844875939.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],color='Green')
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],color="#F57C2B")
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Types Name

sns.barplot(df['TypeName'],color="#d4ee43")
# Out:
# <Axes: ylabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],color="#71C4FC")
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new_df=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['x_res']=new_df[0]
df['y_res']=new_df[1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['x_res'].astype('int32')
df['y_res'].astype('int32')
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1298    1080
# 1299    1800
# 1300     768
# 1301     768
# 1302     768
# Name: y_res, Length: 1303, dtype: int32

# %%
df.drop(columns=['ScreenResolution'],inplace=True,errors='ignore')
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...

# %%
# Convert columns to numeric
df['x_res'] = pd.to_numeric(df['x_res'], errors='coerce')
df['y_res'] = pd.to_numeric(df['y_res'], errors='coerce')
df['Inches'] = pd.to_numeric(df['Inches'], errors='coerce')

# Calculate PPI
df['ppi'] = (np.sqrt(df['x_res']**2 + df['y_res']**2) / df['Inches']).astype(float)

df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...

# %%
df.drop(columns=['x_res','y_res','Inches'],inplace=True,errors='ignore')
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['cpu_name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
def fetch_processer(text):
    text = text.lower()
    if 'intel' in text:
        return 'Intel'
    elif 'amd' in text:
        return 'AMD'
    elif 'apple' in text:
        return 'Apple'
    else:
        return 'Other'

# %%
df['cpu_brand'] = df['cpu_name'].apply(fetch_processer)
df.head(15)
# Out:
#    Company   TypeName                         Cpu  Ram               Memory  \
# 0    Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1    Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2       HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3    Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4    Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
# 5     Acer   Notebook     AMD A9-Series 9420 3GHz    4            500GB HDD
# 6    Apple  Ultrabook        Intel Core i7 2.2GHz   16  256GB Flash Storage
# 7    Apple  Ultrabook        Intel Core i5 1.8GHz    8  256GB Flash Storage
# 8     Asus  Ultrabook  Intel Core i7 8550U 1.8GHz   16            512GB SSD
# 9     Acer  Ultrabook  Intel Core i5 8250U 1.6GHz    8            256GB SSD
# 10      HP   Notebook  Intel Core i5 7200U 2.5GHz    4            500GB HDD
# ...

# %%
sns.barplot(x=df['cpu_brand'],y=df['Price'],color='green')
# Out:
# <Axes: xlabel='cpu_brand', ylabel='Price'>

# %%
df.drop(columns=['cpu_name','Cpu'],inplace=True,errors='ignore')
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df.drop(columns=['Gpu'],inplace=True,errors='ignore')
df
# Out:
#      Company            TypeName  Ram               Memory       OpSys  \
# 0      Apple           Ultrabook    8            128GB SSD       macOS
# 1      Apple           Ultrabook    8  128GB Flash Storage       macOS
# 2         HP            Notebook    8            256GB SSD       No OS
# 3      Apple           Ultrabook   16            512GB SSD       macOS
# 4      Apple           Ultrabook    8            256GB SSD       macOS
# ...      ...                 ...  ...                  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD  Windows 10
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD  Windows 10
# 1300  Lenovo            Notebook    2   64GB Flash Storage  Windows 10
# 1301      HP            Notebook    6              1TB HDD  Windows 10
# 1302    Asus            Notebook    4            500GB HDD  Windows 10
#
#       Weight        Price  Touchscreen  IPS         ppi cpu_brand Gpu_brand
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def os_cat(inp):
    if inp==' Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return " windos"
    else :
        if inp=="macOS" or inp=="macOS 10 S":
            return "mac"
        else:
            return "other No OS/Chrome OS/Android"

# %%
df['Os']=df['OpSys'].apply(os_cat)
df
# Out:
#      Company            TypeName  Ram               Memory       OpSys  \
# 0      Apple           Ultrabook    8            128GB SSD       macOS
# 1      Apple           Ultrabook    8  128GB Flash Storage       macOS
# 2         HP            Notebook    8            256GB SSD       No OS
# 3      Apple           Ultrabook   16            512GB SSD       macOS
# 4      Apple           Ultrabook    8            256GB SSD       macOS
# ...      ...                 ...  ...                  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD  Windows 10
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD  Windows 10
# 1300  Lenovo            Notebook    2   64GB Flash Storage  Windows 10
# 1301      HP            Notebook    6              1TB HDD  Windows 10
# 1302    Asus            Notebook    4            500GB HDD  Windows 10
#
#       Weight        Price  Touchscreen  IPS         ppi cpu_brand Gpu_brand  \
# ...

# %%
df.drop(columns=['OpSys'],inplace=True,errors='ignore')
df
# Out:
#      Company            TypeName  Ram               Memory  Weight  \
# 0      Apple           Ultrabook    8            128GB SSD    1.37
# 1      Apple           Ultrabook    8  128GB Flash Storage    1.34
# 2         HP            Notebook    8            256GB SSD    1.86
# 3      Apple           Ultrabook   16            512GB SSD    1.83
# 4      Apple           Ultrabook    8            256GB SSD    1.37
# ...      ...                 ...  ...                  ...     ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD    1.80
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD    1.30
# 1300  Lenovo            Notebook    2   64GB Flash Storage    1.50
# 1301      HP            Notebook    6              1TB HDD    2.19
# 1302    Asus            Notebook    4            500GB HDD    2.20
#
#             Price  Touchscreen  IPS         ppi cpu_brand Gpu_brand  \
# 0      71378.6832            0    1  226.983005     Intel     Intel
# ...

# %%
df.select_dtypes(include='number').corr()
corr = df.select_dtypes(include='number').corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True,fmt=".2f")
plt.title("Correlation Matrix (Numeric Columns Only)")
plt.show()

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\Adarsh1728\AppData\Local\Temp\ipykernel_16284\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])
x
# Out:
#      Company            TypeName  Ram               Memory  Weight  \
# 0      Apple           Ultrabook    8            128GB SSD    1.37
# 1      Apple           Ultrabook    8  128GB Flash Storage    1.34
# 2         HP            Notebook    8            256GB SSD    1.86
# 3      Apple           Ultrabook   16            512GB SSD    1.83
# 4      Apple           Ultrabook    8            256GB SSD    1.37
# ...      ...                 ...  ...                  ...     ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD    1.80
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD    1.30
# 1300  Lenovo            Notebook    2   64GB Flash Storage    1.50
# 1301      HP            Notebook    6              1TB HDD    2.19
# 1302    Asus            Notebook    4            500GB HDD    2.20
#
#       Touchscreen  IPS         ppi cpu_brand Gpu_brand  \
# 0               0    1  226.983005     Intel     Intel
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1303, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#      Company            TypeName  Ram                Memory  Weight  \
# 10        HP            Notebook    4             500GB HDD    1.86
# 147     Asus            Notebook    4               1TB HDD    2.00
# 1287      HP            Notebook    6               1TB HDD    2.19
# 767     Dell              Gaming   16  128GB SSD +  1TB HDD    2.72
# 816    Razer           Ultrabook   16             512GB SSD    1.29
# ...      ...                 ...  ...                   ...     ...
# 1095    Acer            Notebook    8  256GB SSD +  1TB HDD    2.40
# 1130      HP            Notebook    8               2TB HDD    2.04
# 1294      HP            Notebook    6          1.0TB Hybrid    2.04
# 860   Lenovo            Notebook    8               1TB HDD    2.30
# 1126  Lenovo  2 in 1 Convertible    4    64GB Flash Storage    0.69
#
#       Touchscreen  IPS         ppi cpu_brand Gpu_brand  \
# 10              0    0  100.454670     Intel     Intel
# ...

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error
import pickle

# Categorical columns
categorical_cols = x_train.select_dtypes(include='object').columns.tolist()
print("Categorical columns:", categorical_cols)

# Column Transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols)
], remainder='passthrough')

# BaggingRegressor using LinearRegression
model = LinearRegression()
step2 = BaggingRegressor(
    estimator=model,        # ✅ FIXED: use `estimator` instead of `base_estimator`
    n_estimators=100,
    random_state=3,
    max_samples=0.5,
    max_features=0.75,
    bootstrap=True
)

# Pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train & Evaluate
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)

print('✅ R2 score:', r2_score(y_test, y_pred))
print('✅ MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# Categorical columns: ['Company', 'TypeName', 'Memory', 'cpu_brand', 'Gpu_brand', 'Os']
# ✅ R2 score: 0.7774135313357903
# ✅ MAE: 0.22625802247284194
# c:\Users\Adarsh1728\Desktop\Data_Analyst_Projects\ML\DA_ML_Project\Laptop Price Predictor_ML_Project\.venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ## Exporting the model

# %%
# Save model
with open("pipe.pkl", "wb") as f:
    pickle.dump(pipe, f)

# Save example df for UI
with open("df.pkl", "wb") as f:
    pickle.dump(x_train, f)
